# %% [markdown]
# ## 1. Preliminary
#
# ### 1.1 Context
#
# Vous travaillez pour la ville de Seattle. Pour atteindre son objectif de ville neutre en émissions de carbone en 2050, votre équipe s’intéresse de près à la consommation et aux émissions des bâtiments non destinés à l’habitation.
#
# Des relevés minutieux ont été effectués par les agents de la ville en 2016. Voici [les données](https://s3.eu-west-1.amazonaws.com/course.oc-static.com/projects/Data_Scientist_P4/2016_Building_Energy_Benchmarking.csv) et [leur source](https://data.seattle.gov/dataset/2016-Building-Energy-Benchmarking/2bpz-gwpy). Cependant, ces relevés sont coûteux à obtenir, et à partir de ceux déjà réalisés, **vous voulez tenter de prédire les émissions de CO2 et la consommation totale d’énergie de bâtiments non destinés à l’habitation** pour lesquels elles n’ont pas encore été mesurées.
#
# <div class="alert alert-block alert-info">
# Votre prédiction se basera sur les données structurelles des bâtiments (taille et usage des bâtiments, date de construction, situation géographique, ...)
# </div>
#
# Vous cherchez également à **évaluer l’intérêt de l’"[ENERGY STAR Score](https://www.energystar.gov/buildings/facility-owners-and-managers/existing-buildings/use-portfolio-manager/interpret-your-results/what)" pour la prédiction d’émissions**, qui est fastidieux à calculer avec l’approche utilisée actuellement par votre équipe. Vous l'intégrerez dans la modélisation et jugerez de son intérêt.
# Vous sortez tout juste d’une réunion de brief avec votre équipe. Voici un récapitulatif de votre mission :
#  1) Réaliser une courte analyse exploratoire.
#  2) Tester différents modèles de prédiction afin de répondre au mieux à la problématique.
#
# Avant de quitter la salle de brief, Douglas, le project lead, vous donne quelques pistes et erreurs à éviter :
#
# > Douglas : L’objectif est de te passer des relevés de consommation annuels futurs (attention à la fuite de données). Nous ferons de toute façon pour tout nouveau bâtiment un premier relevé de référence la première année, donc rien ne t'interdit d’en déduire des variables structurelles aux bâtiments, par exemple la nature et proportions des sources d’énergie utilisées..
# Fais bien attention au traitement des différentes variables, à la fois pour trouver de nouvelles informations (peut-on déduire des choses intéressantes d’une simple adresse ?) et optimiser les performances en appliquant des transformations simples aux variables (normalisation, passage au log, etc.).
# Mets en place une évaluation rigoureuse des performances de la régression, et optimise les hyperparamètres et le choix d’algorithmes de ML à l’aide d’une validation croisée.

# %% [markdown]
# ### 1.2 Requirements

# %%
package_list = ("pandas", "numpy", "matplotlib", "seaborn", "scikit-learn", "mlflow")

# %%
# !python3 -V
# Out:
# Python 3.10.13

# %%
txt = !python3 -m pip freeze
check = lambda i: any([(pack in i) for pack in package_list])
txt = [i for i in txt if check(i)]
txt
# Out:
# ['matplotlib==3.8.2',
#  'matplotlib-inline==0.1.6',
#  'mlflow==2.11.3',
#  'numpy @ file:///Users/runner/miniforge3/conda-bld/numpy_1704280780572/work/dist/numpy-1.26.3-cp310-cp310-macosx_11_0_arm64.whl#sha256=f96d0b051b72345dbc317d793b2b34c7c4b7f41b0b791ffc93e820c45ba6a91c',
#  'pandas==2.2.0',
#  'scikit-learn==1.4.0',
#  'seaborn==0.13.2']

# %% [markdown]
# ### 1.3 Imports

# %%
# built in
import os, warnings
import time

# data
import pandas as pd
import numpy as np

# metrics
from sklearn.metrics import mean_squared_error, r2_score

# estimators
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.dummy import DummyRegressor
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet, Perceptron
from sklearn.neural_network import MLPRegressor

# model selection
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV

## mlflow
import mlflow
import mlflow.sklearn

# visualization
import matplotlib.pyplot as plt
import seaborn as sns

# exceptions
from sklearn.exceptions import ConvergenceWarning

# pipeline et preprocessing
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.impute import KNNImputer

# %% [markdown]
# ### 1.4 Graphics and option

# %%
# warnings.filterwarnings('ignore)
warnings.filterwarnings(action='once')

# Suppress specific warnings
warnings.filterwarnings("ignore", category=UserWarning, module='_distutils_hack')
warnings.filterwarnings("ignore", category=DeprecationWarning, module='importlib')

# Ignore ConvergenceWarning
warnings.filterwarnings("ignore", category=ConvergenceWarning)

# %% [markdown]
# <div class="alert alert-block alert-info">
# We disable the warnings.</div>

# %% [markdown]
# ### 1.5 Data

# %%
# !tree

# %%
# os.listdir()

# %%
path="./data/cleaned/"
filename="df_SiteEnergyUseWN_0.csv"

# %%
df = pd.read_csv(path+filename)
df.head()
# Out:
#   Neighborhood GroupedPrimaryPropertyTypes  YearBuilt  NumberofBuildings  \
# 0     DOWNTOWN     Bâtiments d'Hébergement     1927.0                1.0
# 1     DOWNTOWN     Bâtiments d'Hébergement     1996.0                1.0
# 2     DOWNTOWN     Bâtiments d'Hébergement     1969.0                1.0
# 3     DOWNTOWN     Bâtiments d'Hébergement     1926.0                1.0
# 4     DOWNTOWN     Bâtiments d'Hébergement     1980.0                1.0
#
#    NumberofFloors  PropertyGFABuilding(s)  ENERGYSTARScore  \
# 0            12.0                 88434.0             60.0
# 1            11.0                 88502.0             61.0
# 2            41.0                759392.0             43.0
# 3            10.0                 61320.0             56.0
# 4            18.0                113580.0             75.0
#
#    DistanceToDowntown  Log_SiteEnergyUseWN(kBtu)
# 0            0.864611                  15.824652
# 1            0.907278                  15.974742
# 2            1.047606                  18.118725
# 3            1.038057                  15.753792
# 4            1.100255                  16.500395

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1379 entries, 0 to 1378
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Neighborhood                 1379 non-null   object
#  1   GroupedPrimaryPropertyTypes  1379 non-null   object
#  2   YearBuilt                    1379 non-null   float64
#  3   NumberofBuildings            1379 non-null   float64
#  4   NumberofFloors               1379 non-null   float64
#  5   PropertyGFABuilding(s)       1379 non-null   float64
#  6   ENERGYSTARScore              924 non-null    float64
#  7   DistanceToDowntown           1379 non-null   float64
#  8   Log_SiteEnergyUseWN(kBtu)    1379 non-null   float64
# dtypes: float64(7), object(2)
# memory usage: 97.1+ KB

# %% [markdown]
# ## 2. Data Preparation

# %% [markdown]
# ### 2.1 X & y

# %%
X = df.drop(columns="Log_SiteEnergyUseWN(kBtu)")
y = df['Log_SiteEnergyUseWN(kBtu)']

# %%
X.head()
# Out:
#   Neighborhood GroupedPrimaryPropertyTypes  YearBuilt  NumberofBuildings  \
# 0     DOWNTOWN     Bâtiments d'Hébergement     1927.0                1.0
# 1     DOWNTOWN     Bâtiments d'Hébergement     1996.0                1.0
# 2     DOWNTOWN     Bâtiments d'Hébergement     1969.0                1.0
# 3     DOWNTOWN     Bâtiments d'Hébergement     1926.0                1.0
# 4     DOWNTOWN     Bâtiments d'Hébergement     1980.0                1.0
#
#    NumberofFloors  PropertyGFABuilding(s)  ENERGYSTARScore  DistanceToDowntown
# 0            12.0                 88434.0             60.0            0.864611
# 1            11.0                 88502.0             61.0            0.907278
# 2            41.0                759392.0             43.0            1.047606
# 3            10.0                 61320.0             56.0            1.038057
# 4            18.0                113580.0             75.0            1.100255

# %%
y.head()
# Out:
# 0    15.824652
# 1    15.974742
# 2    18.118725
# 3    15.753792
# 4    16.500395
# Name: Log_SiteEnergyUseWN(kBtu), dtype: float64

# %% [markdown]
# ## 3. Models for different k-values (knn imputation)

# %%
# Configurer MLflow
mlflow.set_experiment('Gradient_Boosting_Energy_k_val')

# Initialiser le DataFrame des résultats
results_df = pd.DataFrame(columns=['Model Name', 'Best Parameters', 'MSE Train', 'MSE Test', 'R2 Train', 'R2 Test', 'Best CV R2 Test', 'Fit Time'])

def train_eval_model(model, X_train, y_train, X_test, y_test, model_name, best_params=None, best_cv_score=None):
    # Set model parameters if provided
    if best_params:
        model.set_params(**best_params)

    # Mesurer le temps de début
    start_time = time.time()
    # Entraîner le modèle
    model.fit(X_train, y_train)
    # Mesurer le temps de fin et calculer le temps de fitting
    fit_time = time.time() - start_time

    # Prédictions sur les données d'entraînement et de test
    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)

    # Calcul des métriques de performance
    mse_train = mean_squared_error(y_train, y_train_pred)
    mse_test = mean_squared_error(y_test, y_test_pred)
    r2_train = r2_score(y_train, y_train_pred)
    r2_test = r2_score(y_test, y_test_pred)

    # Enregistrement de la performance du modèle avec MLflow
    with mlflow.start_run(run_name=f"{model_name}"):
        if best_params:
            mlflow.log_params(best_params)
        mlflow.log_metric("mse_train", mse_train)
        mlflow.log_metric("mse_test", mse_test)
        mlflow.log_metric("r2_train", r2_train)
        mlflow.log_metric("r2_test", r2_test)
        if best_cv_score is not None:
            mlflow.log_metric("best_cv_r2_test", best_cv_score)
        mlflow.sklearn.log_model(model, f"model_{model_name}")

        print(f"{model_name} - MSE Train: {mse_train}, MSE Test: {mse_test}, R2 Train: {r2_train}, R2 Test: {r2_test}")

    # # Plotting the predicted vs real values
    # plt.figure(figsize=(10, 6))
    # plt.scatter(y_test, y_test_pred, alpha=0.5)
    # plt.xlabel('Real Values')
    # plt.ylabel('Predicted Values')
    # plt.title(f'Comparison of Real and Predicted Values for {model_name}')
    # plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=2)  # Diagonal line
    # plt.savefig(f'predicted_vs_real_{model_name}_v1.png')
    # plt.show()
    
    
    # # Calcul des résidus
    # residuals = y_test - y_test_pred

    # # Tracer le graphique des résidus
    # plt.figure(figsize=(10, 6))
    # plt.scatter(y_test_pred, residuals, alpha=0.5)
    # plt.xlabel('Predicted Values')
    # plt.ylabel('Residuals')
    # plt.title(f'Residual Plot for {model_name}')
    # plt.axhline(y=0, color='k', linestyle='--')  # Ligne horizontale à zéro
    # plt.savefig(f'residual_plot_{model_name}_v1.png')
    # plt.show()
    
    # # Tracer l'histogramme des résidus
    # plt.figure(figsize=(10, 6))
    # plt.hist(residuals, bins=30, edgecolor='k', alpha=0.7)
    # plt.xlabel('Residuals')
    # plt.ylabel('Frequency')
    # plt.title(f'Histogram of Residuals for {model_name}')
    # plt.savefig(f'residuals_histogram_{model_name}_v1.png')
    # plt.show()

    # # Tracer le tracé KDE des résidus
    # plt.figure(figsize=(10, 6))
    # sns.kdeplot(residuals, shade=True)
    # plt.xlabel('Residuals')
    # plt.ylabel('Density')
    # plt.title(f'KDE Plot of Residuals for {model_name}')
    # plt.savefig(f'residuals_kde_{model_name}_v1.png')
    # plt.show()


    # Enregistrement des résultats dans le DataFrame
    global results_df
    new_row = pd.DataFrame([{
        'Model Name': model_name,
        'Best Parameters': best_params,
        'MSE Train': mse_train,
        'MSE Test': mse_test,
        'R2 Train': r2_train,
        'R2 Test': r2_test,
        'Best CV R2 Test': best_cv_score,
        'Fit Time': fit_time
    }])
    results_df = pd.concat([results_df, new_row], ignore_index=True)
# Out:
# 2024/04/24 07:36:47 INFO mlflow.tracking.fluent: Experiment with name 'Gradient_Boosting_Energy_k_val' does not exist. Creating a new experiment.

# %%
for k in range(15, 30):
    X_train, X_test, y_train, y_test = train_test_split(X,
                                                        y,
                                                        test_size=0.3,
                                                        random_state=42)

    numeric_features = X_train.select_dtypes(include=['int64', 'float64']).columns
    categorical_features = X_train.select_dtypes(include=['object', 'category']).columns

    pipe_trans_num = Pipeline(steps=[('scaler', StandardScaler())])
    pipe_trans_cat = Pipeline(steps=[('ohe', OneHotEncoder())])

    preprocessor = ColumnTransformer(
        transformers=[
            ('num', pipe_trans_num, numeric_features),
            ('cat', pipe_trans_cat, categorical_features)
        ])

    k_val = k

    model_pipelines = {
        f"GradientBoosting_k_{k}": Pipeline([("preprocessor", preprocessor), ("imputer", KNNImputer(n_neighbors=k_val)), ("model", GradientBoostingRegressor())])
    }
    
    param_grids = {
        f"GradientBoosting_k_{k}": {'model__n_estimators': [150], 'model__learning_rate': [0.1], 
                            'model__max_depth': [2], 
                            'model__min_samples_split': [20], 'model__min_samples_leaf':[10], 
                            'model__max_features': [.75]}
    }

    # Recherche des meilleurs hyperparamètres et enregistrement du meilleur score de validation croisée
    best_params = {}
    best_cv_scores = {}

    for model_name, param_grid in param_grids.items():
        model = model_pipelines[model_name]

        if param_grid:
            grid_search = GridSearchCV(model, param_grid, cv=5, scoring='r2', verbose=1)
            grid_search.fit(X_train, y_train)
            best_params[model_name] = grid_search.best_params_
            best_cv_scores[model_name] = max(grid_search.cv_results_['mean_test_score'])
        else:
            best_params[model_name] = None
            best_cv_scores[model_name] = None

    # Entraînement, évaluation et enregistrement des meilleurs modèles
    for model_name, params in best_params.items():
        model = model_pipelines[model_name]

        train_eval_model(model, X_train, y_train, X_test, y_test, model_name, params, best_cv_scores[model_name])
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# GradientBoosting_k_15 - MSE Train: 0.30143983241375194, MSE Test: 0.39119495406397103, R2 Train: 0.8258603851685943, R2 Test: 0.7314639295655931
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /var/folders/17/7v9_fz593_xfss9zy0542f940000gn/T/ipykernel_71436/3562622476.py:98: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, new_row], ignore_index=True)
# GradientBoosting_k_16 - MSE Train: 0.3034979684838686, MSE Test: 0.3948662163516336, R2 Train: 0.8246714148203464, R2 Test: 0.7289437888070758
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# GradientBoosting_k_17 - MSE Train: 0.3000495293912457, MSE Test: 0.3976022437016386, R2 Train: 0.8266635531869001, R2 Test: 0.7270656407749023
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# GradientBoosting_k_18 - MSE Train: 0.3076554600365407, MSE Test: 0.394858580801859, R2 Train: 0.8222696619668834, R2 Test: 0.7289490302359612
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# GradientBoosting_k_19 - MSE Train: 0.30332287267236563, MSE Test: 0.39245120817488527, R2 Train: 0.8247725664064842, R2 Test: 0.730601572986329
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# GradientBoosting_k_20 - MSE Train: 0.2994447314892801, MSE Test: 0.3989778344373744, R2 Train: 0.8270129405683082, R2 Test: 0.7261213654797767
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# GradientBoosting_k_21 - MSE Train: 0.3057608119223442, MSE Test: 0.3961266944171685, R2 Train: 0.8233641865033567, R2 Test: 0.7280785326909854
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# GradientBoosting_k_22 - MSE Train: 0.2993448641731537, MSE Test: 0.39362769883506865, R2 Train: 0.8270706331958062, R2 Test: 0.7297939700878091
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# GradientBoosting_k_23 - MSE Train: 0.30074340143627165, MSE Test: 0.39852462756756046, R2 Train: 0.8262627083161491, R2 Test: 0.7264324696764166
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# GradientBoosting_k_24 - MSE Train: 0.30170058312513476, MSE Test: 0.389311370839905, R2 Train: 0.8257097513652126, R2 Test: 0.7327569166863936
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# GradientBoosting_k_25 - MSE Train: 0.3022365953872287, MSE Test: 0.3959752555816845, R2 Train: 0.8254001009513356, R2 Test: 0.7281824879935004
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# GradientBoosting_k_26 - MSE Train: 0.3003491249323926, MSE Test: 0.4004872430063193, R2 Train: 0.8264904790058181, R2 Test: 0.7250852308324003
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# GradientBoosting_k_27 - MSE Train: 0.30315860812761786, MSE Test: 0.3943338654472407, R2 Train: 0.8248674608480175, R2 Test: 0.7293092214857767
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# GradientBoosting_k_28 - MSE Train: 0.3032715917386946, MSE Test: 0.4039855879451685, R2 Train: 0.8248021910316247, R2 Test: 0.7226837893180267
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# GradientBoosting_k_29 - MSE Train: 0.3009605851833652, MSE Test: 0.39795500719315263, R2 Train: 0.8261372428334899, R2 Test: 0.7268234860108396

# %%
results_df.head(50)
# Out:
#                Model Name                                    Best Parameters  \
# 0   GradientBoosting_k_15  {'model__learning_rate': 0.1, 'model__max_dept...
# 1   GradientBoosting_k_16  {'model__learning_rate': 0.1, 'model__max_dept...
# 2   GradientBoosting_k_17  {'model__learning_rate': 0.1, 'model__max_dept...
# 3   GradientBoosting_k_18  {'model__learning_rate': 0.1, 'model__max_dept...
# 4   GradientBoosting_k_19  {'model__learning_rate': 0.1, 'model__max_dept...
# 5   GradientBoosting_k_20  {'model__learning_rate': 0.1, 'model__max_dept...
# 6   GradientBoosting_k_21  {'model__learning_rate': 0.1, 'model__max_dept...
# 7   GradientBoosting_k_22  {'model__learning_rate': 0.1, 'model__max_dept...
# 8   GradientBoosting_k_23  {'model__learning_rate': 0.1, 'model__max_dept...
# 9   GradientBoosting_k_24  {'model__learning_rate': 0.1, 'model__max_dept...
# 10  GradientBoosting_k_25  {'model__learning_rate': 0.1, 'model__max_dept...
# 11  GradientBoosting_k_26  {'model__learning_rate': 0.1, 'model__max_dept...
# 12  GradientBoosting_k_27  {'model__learning_rate': 0.1, 'model__max_dept...
# 13  GradientBoosting_k_28  {'model__learning_rate': 0.1, 'model__max_dept...
# 14  GradientBoosting_k_29  {'model__learning_rate': 0.1, 'model__max_dept...
#
#     MSE Train  MSE Test  R2 Train   R2 Test  Best CV R2 Test  Fit Time
# 0    0.301440  0.391195  0.825860  0.731464         0.764807  0.163615
# 1    0.303498  0.394866  0.824671  0.728944         0.761582  0.369276
# 2    0.300050  0.397602  0.826664  0.727066         0.765888  0.372341
# 3    0.307655  0.394859  0.822270  0.728949         0.762644  0.339549
# 4    0.303323  0.392451  0.824773  0.730602         0.762513  0.342522
# 5    0.299445  0.398978  0.827013  0.726121         0.761957  0.339938
# 6    0.305761  0.396127  0.823364  0.728079         0.758803  0.382661
# 7    0.299345  0.393628  0.827071  0.729794         0.757642  0.308420
# 8    0.300743  0.398525  0.826263  0.726432         0.761511  0.315599
# 9    0.301701  0.389311  0.825710  0.732757         0.760058  0.328517
# 10   0.302237  0.395975  0.825400  0.728182         0.767834  0.317098
# 11   0.300349  0.400487  0.826490  0.725085         0.762131  0.243167
# 12   0.303159  0.394334  0.824867  0.729309         0.759854  0.241397
# 13   0.303272  0.403986  0.824802  0.722684         0.765598  0.350601
# 14   0.300961  0.397955  0.826137  0.726823         0.761461  0.353499

# %%
# Retrieve the current MLflow experiment name
mlflow_experiment_name = mlflow.get_experiment_by_name('Gradient_Boosting_Energy_k_val').name

# Construct a filename using the experiment name
filename = f"{mlflow_experiment_name}_results.csv"

# Save the DataFrame
results_df.to_csv(filename, index=False)
print(f"Results saved as {filename}")
# Out:
# Results saved as Gradient_Boosting_Energy_k_val_results.csv

# %% [markdown]
# ## 4. Models for different train_test_split

# %%
# Configurer MLflow
mlflow.set_experiment('Gradient_Boosting_Energy_train_test')

# Initialiser le DataFrame des résultats
results_df = pd.DataFrame(columns=['Model Name', 'Best Parameters', 'MSE Train', 'MSE Test', 'R2 Train', 'R2 Test', 'Best CV R2 Test', 'Fit Time'])

def train_eval_model(model, X_train, y_train, X_test, y_test, model_name, best_params=None, best_cv_score=None):
    # Set model parameters if provided
    if best_params:
        model.set_params(**best_params)

    # Mesurer le temps de début
    start_time = time.time()
    # Entraîner le modèle
    model.fit(X_train, y_train)
    # Mesurer le temps de fin et calculer le temps de fitting
    fit_time = time.time() - start_time

    # Prédictions sur les données d'entraînement et de test
    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)

    # Calcul des métriques de performance
    mse_train = mean_squared_error(y_train, y_train_pred)
    mse_test = mean_squared_error(y_test, y_test_pred)
    r2_train = r2_score(y_train, y_train_pred)
    r2_test = r2_score(y_test, y_test_pred)

    # Enregistrement de la performance du modèle avec MLflow
    with mlflow.start_run(run_name=f"{model_name}"):
        if best_params:
            mlflow.log_params(best_params)
        mlflow.log_metric("mse_train", mse_train)
        mlflow.log_metric("mse_test", mse_test)
        mlflow.log_metric("r2_train", r2_train)
        mlflow.log_metric("r2_test", r2_test)
        if best_cv_score is not None:
            mlflow.log_metric("best_cv_r2_test", best_cv_score)
        mlflow.sklearn.log_model(model, f"model_{model_name}")

        print(f"{model_name} - MSE Train: {mse_train}, MSE Test: {mse_test}, R2 Train: {r2_train}, R2 Test: {r2_test}")

    # # Plotting the predicted vs real values
    # plt.figure(figsize=(10, 6))
    # plt.scatter(y_test, y_test_pred, alpha=0.5)
    # plt.xlabel('Real Values')
    # plt.ylabel('Predicted Values')
    # plt.title(f'Comparison of Real and Predicted Values for {model_name}')
    # plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=2)  # Diagonal line
    # plt.savefig(f'predicted_vs_real_{model_name}_v1.png')
    # plt.show()
    
    
    # # Calcul des résidus
    # residuals = y_test - y_test_pred

    # # Tracer le graphique des résidus
    # plt.figure(figsize=(10, 6))
    # plt.scatter(y_test_pred, residuals, alpha=0.5)
    # plt.xlabel('Predicted Values')
    # plt.ylabel('Residuals')
    # plt.title(f'Residual Plot for {model_name}')
    # plt.axhline(y=0, color='k', linestyle='--')  # Ligne horizontale à zéro
    # plt.savefig(f'residual_plot_{model_name}_v1.png')
    # plt.show()
    
    # # Tracer l'histogramme des résidus
    # plt.figure(figsize=(10, 6))
    # plt.hist(residuals, bins=30, edgecolor='k', alpha=0.7)
    # plt.xlabel('Residuals')
    # plt.ylabel('Frequency')
    # plt.title(f'Histogram of Residuals for {model_name}')
    # plt.savefig(f'residuals_histogram_{model_name}_v1.png')
    # plt.show()

    # # Tracer le tracé KDE des résidus
    # plt.figure(figsize=(10, 6))
    # sns.kdeplot(residuals, shade=True)
    # plt.xlabel('Residuals')
    # plt.ylabel('Density')
    # plt.title(f'KDE Plot of Residuals for {model_name}')
    # plt.savefig(f'residuals_kde_{model_name}_v1.png')
    # plt.show()


    # Enregistrement des résultats dans le DataFrame
    global results_df
    new_row = pd.DataFrame([{
        'Model Name': model_name,
        'Best Parameters': best_params,
        'MSE Train': mse_train,
        'MSE Test': mse_test,
        'R2 Train': r2_train,
        'R2 Test': r2_test,
        'Best CV R2 Test': best_cv_score,
        'Fit Time': fit_time
    }])
    results_df = pd.concat([results_df, new_row], ignore_index=True)
# Out:
# 2024/04/24 07:38:07 INFO mlflow.tracking.fluent: Experiment with name 'Gradient_Boosting_Energy_train_test' does not exist. Creating a new experiment.

# %%
for k in [15]:
    for i in range(50):
        X_train, X_test, y_train, y_test = train_test_split(X,
                                                            y,
                                                            test_size=0.3,
                                                            random_state=i
                                                            )

        numeric_features = X_train.select_dtypes(include=['int64', 'float64']).columns
        categorical_features = X_train.select_dtypes(include=['object', 'category']).columns

        pipe_trans_num = Pipeline(steps=[('scaler', StandardScaler())])
        pipe_trans_cat = Pipeline(steps=[('ohe', OneHotEncoder())])

        preprocessor = ColumnTransformer(
            transformers=[
                ('num', pipe_trans_num, numeric_features),
                ('cat', pipe_trans_cat, categorical_features)
            ])

        k_val = k

        model_pipelines = {
            f"GradientBoosting_train_test_k_{k_val}_{i}": Pipeline([("preprocessor", preprocessor), ("imputer", KNNImputer(n_neighbors=k_val)), ("model", GradientBoostingRegressor())])
        }
        
        param_grids = {
            f"GradientBoosting_train_test_k_{k_val}_{i}": {'model__n_estimators': [150], 'model__learning_rate': [0.1], 
                            'model__max_depth': [2], 
                            'model__min_samples_split': [20], 'model__min_samples_leaf':[10], 
                            'model__max_features': [.75]}
                    }

        # Recherche des meilleurs hyperparamètres et enregistrement du meilleur score de validation croisée
        best_params = {}
        best_cv_scores = {}

        for model_name, param_grid in param_grids.items():
            model = model_pipelines[model_name]

            if param_grid:
                grid_search = GridSearchCV(model, param_grid, cv=5, scoring='r2', verbose=1)
                grid_search.fit(X_train, y_train)
                best_params[model_name] = grid_search.best_params_
                best_cv_scores[model_name] = max(grid_search.cv_results_['mean_test_score'])
            else:
                best_params[model_name] = None
                best_cv_scores[model_name] = None

        # Entraînement, évaluation et enregistrement des meilleurs modèles
        for model_name, params in best_params.items():
            model = model_pipelines[model_name]

            train_eval_model(model, X_train, y_train, X_test, y_test, model_name, params, best_cv_scores[model_name])
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# GradientBoosting_train_test_k_15_0 - MSE Train: 0.3111165240969761, MSE Test: 0.3779214267737809, R2 Train: 0.8142197669113527, R2 Test: 0.7636348877462965
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /var/folders/17/7v9_fz593_xfss9zy0542f940000gn/T/ipykernel_71436/1856013352.py:98: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, new_row], ignore_index=True)
# GradientBoosting_train_test_k_15_1 - MSE Train: 0.3060617484125429, MSE Test: 0.36698360600074414, R2 Train: 0.8214908312489038, R2 Test: 0.7562956193510273
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# GradientBoosting_train_test_k_15_2 - MSE Train: 0.2840678465890933, MSE Test: 0.4281828139920785, R2 Train: 0.8275924082301028, R2 Test: 0.7415187751723378
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# GradientBoosting_train_test_k_15_3 - MSE Train: 0.2912765879509667, MSE Test: 0.4337219071594727, R2 Train: 0.8236002477509149, R2 Test: 0.7376678415597557
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# GradientBoosting_train_test_k_15_4 - MSE Train: 0.30659395791166416, MSE Test: 0.4036678962937263, R2 Train: 0.8201598693462702, R2 Test: 0.7359000384009782
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# GradientBoosting_train_test_k_15_5 - MSE Train: 0.31081352464905104, MSE Test: 0.39597168486354184, R2 Train: 0.8138524211724316, R2 Test: 0.7541161226587209
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# GradientBoosting_train_test_k_15_6 - MSE Train: 0.2699552893987741, MSE Test: 0.46930871816882086, R2 Train: 0.8316324179087944, R2 Test: 0.7338167748004929
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# GradientBoosting_train_test_k_15_7 - MSE Train: 0.29215982070526925, MSE Test: 0.430512743572176, R2 Train: 0.8191527588351462, R2 Test: 0.7487696666250363
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# GradientBoosting_train_test_k_15_8 - MSE Train: 0.30150138625212025, MSE Test: 0.38979499945693846, R2 Train: 0.8141773738202658, R2 Test: 0.7729031065950964
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# GradientBoosting_train_test_k_15_9 - MSE Train: 0.3038690726889856, MSE Test: 0.41577944018187624, R2 Train: 0.8120341149924941, R2 Test: 0.7602412765878972
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# GradientBoosting_train_test_k_15_10 - MSE Train: 0.29852019970471216, MSE Test: 0.3785737373420943, R2 Train: 0.8227339101147112, R2 Test: 0.7586907010942989
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# GradientBoosting_train_test_k_15_11 - MSE Train: 0.301437494386678, MSE Test: 0.37789901992935987, R2 Train: 0.8234404469221343, R2 Test: 0.7518349410350679
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# GradientBoosting_train_test_k_15_12 - MSE Train: 0.3232928636137982, MSE Test: 0.3711747207644162, R2 Train: 0.7987754410698636, R2 Test: 0.7887367605925298
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# GradientBoosting_train_test_k_15_13 - MSE Train: 0.2949901073762134, MSE Test: 0.4152303796452736, R2 Train: 0.8218190476075806, R2 Test: 0.7456977532437583
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# GradientBoosting_train_test_k_15_14 - MSE Train: 0.30804687362022243, MSE Test: 0.396013653212726, R2 Train: 0.814821029840358, R2 Test: 0.7562683644415592
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# GradientBoosting_train_test_k_15_15 - MSE Train: 0.2999545149739312, MSE Test: 0.3989483731437288, R2 Train: 0.8197206654233138, R2 Test: 0.7537408736499054
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# GradientBoosting_train_test_k_15_16 - MSE Train: 0.3052050352770551, MSE Test: 0.40151054082271337, R2 Train: 0.8147864799599582, R2 Test: 0.7583067886751385
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# GradientBoosting_train_test_k_15_17 - MSE Train: 0.29676119735726836, MSE Test: 0.3985673529393022, R2 Train: 0.8147638799368054, R2 Test: 0.7738598103924448
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# GradientBoosting_train_test_k_15_18 - MSE Train: 0.2860076167058434, MSE Test: 0.4420523885181603, R2 Train: 0.8239323637782052, R2 Test: 0.7420451054985222
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# GradientBoosting_train_test_k_15_19 - MSE Train: 0.2895633540095561, MSE Test: 0.43496098667381405, R2 Train: 0.8194567085247263, R2 Test: 0.7534119758648082
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# GradientBoosting_train_test_k_15_20 - MSE Train: 0.30072934676687013, MSE Test: 0.422376902553983, R2 Train: 0.8193406560391956, R2 Test: 0.7391464947252623
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# GradientBoosting_train_test_k_15_21 - MSE Train: 0.3052977230063053, MSE Test: 0.3873667047327576, R2 Train: 0.8159194609113047, R2 Test: 0.7632052962227556
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# GradientBoosting_train_test_k_15_22 - MSE Train: 0.2864443433367911, MSE Test: 0.4453838138478819, R2 Train: 0.817813018191442, R2 Test: 0.756943576237379
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# GradientBoosting_train_test_k_15_23 - MSE Train: 0.30473682719619216, MSE Test: 0.3711201997745841, R2 Train: 0.825257065547679, R2 Test: 0.7414315135372009
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# GradientBoosting_train_test_k_15_24 - MSE Train: 0.29787228822097334, MSE Test: 0.4180430129629122, R2 Train: 0.8170666196019634, R2 Test: 0.75507878397933
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# GradientBoosting_train_test_k_15_25 - MSE Train: 0.27965094942043023, MSE Test: 0.45391150747752845, R2 Train: 0.8286658942138923, R2 Test: 0.7326444158133434
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# GradientBoosting_train_test_k_15_26 - MSE Train: 0.30820913960691126, MSE Test: 0.36857656033736796, R2 Train: 0.8182010957641519, R2 Test: 0.7594128687730595
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# GradientBoosting_train_test_k_15_27 - MSE Train: 0.3127502837542934, MSE Test: 0.3558483130687501, R2 Train: 0.8097418960882716, R2 Test: 0.785985270307193
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# GradientBoosting_train_test_k_15_28 - MSE Train: 0.28009001036500847, MSE Test: 0.47414183339561294, R2 Train: 0.8270079964231758, R2 Test: 0.7253697151854689
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# GradientBoosting_train_test_k_15_29 - MSE Train: 0.2794540768440699, MSE Test: 0.4931885909249062, R2 Train: 0.8262738438471151, R2 Test: 0.7184724073549189
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# GradientBoosting_train_test_k_15_30 - MSE Train: 0.2986532091793758, MSE Test: 0.3971475669497109, R2 Train: 0.8223146263771122, R2 Test: 0.7493444429434273
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# GradientBoosting_train_test_k_15_31 - MSE Train: 0.32181278066064606, MSE Test: 0.397752106142997, R2 Train: 0.8026479475098305, R2 Test: 0.7658858463566443
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# GradientBoosting_train_test_k_15_32 - MSE Train: 0.29827724141297635, MSE Test: 0.40224400875829086, R2 Train: 0.8231693258512109, R2 Test: 0.7438448876764147
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# GradientBoosting_train_test_k_15_33 - MSE Train: 0.28590187215293283, MSE Test: 0.43257364700058165, R2 Train: 0.828853464825069, R2 Test: 0.7307691196757009
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# GradientBoosting_train_test_k_15_34 - MSE Train: 0.3038959057192179, MSE Test: 0.411484976581682, R2 Train: 0.8210578763518273, R2 Test: 0.7324024961754205
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# GradientBoosting_train_test_k_15_35 - MSE Train: 0.3026100398915976, MSE Test: 0.4182400997055013, R2 Train: 0.81839877542283, R2 Test: 0.740727602256772
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# GradientBoosting_train_test_k_15_36 - MSE Train: 0.28393604801126726, MSE Test: 0.45419929235080636, R2 Train: 0.8225578180250392, R2 Test: 0.743499365026885
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# GradientBoosting_train_test_k_15_37 - MSE Train: 0.30700469193004637, MSE Test: 0.4011999481466042, R2 Train: 0.8143814990505853, R2 Test: 0.7550450859299889
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# GradientBoosting_train_test_k_15_38 - MSE Train: 0.2793986616685226, MSE Test: 0.4470573661754869, R2 Train: 0.8277951360259473, R2 Test: 0.7400546692471024
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# GradientBoosting_train_test_k_15_39 - MSE Train: 0.30700899311526014, MSE Test: 0.3969612532217601, R2 Train: 0.8103978749504362, R2 Test: 0.7702769195647946
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# GradientBoosting_train_test_k_15_40 - MSE Train: 0.28993845058259754, MSE Test: 0.4235874842762175, R2 Train: 0.8230086601205993, R2 Test: 0.7484317049538802
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# GradientBoosting_train_test_k_15_41 - MSE Train: 0.3119711163939075, MSE Test: 0.36453577207949134, R2 Train: 0.819775982022592, R2 Test: 0.7484260316931293
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# GradientBoosting_train_test_k_15_42 - MSE Train: 0.3012763345507874, MSE Test: 0.40261275916352895, R2 Train: 0.8259548367035969, R2 Test: 0.7236261686676859
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# GradientBoosting_train_test_k_15_43 - MSE Train: 0.2961453654896142, MSE Test: 0.44253654896369143, R2 Train: 0.8221030545969797, R2 Test: 0.7260562052236645
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# GradientBoosting_train_test_k_15_44 - MSE Train: 0.2991588672514446, MSE Test: 0.40684703381513715, R2 Train: 0.8219288490308879, R2 Test: 0.7424482741872565
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# GradientBoosting_train_test_k_15_45 - MSE Train: 0.30373559111847603, MSE Test: 0.3767324063599797, R2 Train: 0.8123599384932341, R2 Test: 0.7818210184051215
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# GradientBoosting_train_test_k_15_46 - MSE Train: 0.3050290055321291, MSE Test: 0.3813193731124146, R2 Train: 0.8145762195758783, R2 Test: 0.7712124403340238
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# GradientBoosting_train_test_k_15_47 - MSE Train: 0.30990438843656465, MSE Test: 0.35743876290256654, R2 Train: 0.8187742304804868, R2 Test: 0.764279881020013
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# GradientBoosting_train_test_k_15_48 - MSE Train: 0.30724046217621415, MSE Test: 0.3941351910966666, R2 Train: 0.8173453980886659, R2 Test: 0.7507951138380253
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# GradientBoosting_train_test_k_15_49 - MSE Train: 0.3015909388303328, MSE Test: 0.40601577110002174, R2 Train: 0.8154345753868791, R2 Test: 0.7601958809685271

# %%
results_df.head(50)
# Out:
#                              Model Name  \
# 0    GradientBoosting_train_test_k_15_0
# 1    GradientBoosting_train_test_k_15_1
# 2    GradientBoosting_train_test_k_15_2
# 3    GradientBoosting_train_test_k_15_3
# 4    GradientBoosting_train_test_k_15_4
# 5    GradientBoosting_train_test_k_15_5
# 6    GradientBoosting_train_test_k_15_6
# 7    GradientBoosting_train_test_k_15_7
# 8    GradientBoosting_train_test_k_15_8
# 9    GradientBoosting_train_test_k_15_9
# 10  GradientBoosting_train_test_k_15_10
# 11  GradientBoosting_train_test_k_15_11
# 12  GradientBoosting_train_test_k_15_12
# 13  GradientBoosting_train_test_k_15_13
# 14  GradientBoosting_train_test_k_15_14
# 15  GradientBoosting_train_test_k_15_15
# 16  GradientBoosting_train_test_k_15_16
# 17  GradientBoosting_train_test_k_15_17
# 18  GradientBoosting_train_test_k_15_18
# 19  GradientBoosting_train_test_k_15_19
# 20  GradientBoosting_train_test_k_15_20
# 21  GradientBoosting_train_test_k_15_21
# 22  GradientBoosting_train_test_k_15_22
# 23  GradientBoosting_train_test_k_15_23
# 24  GradientBoosting_train_test_k_15_24
# 25  GradientBoosting_train_test_k_15_25
# 26  GradientBoosting_train_test_k_15_26
# 27  GradientBoosting_train_test_k_15_27
# 28  GradientBoosting_train_test_k_15_28
# 29  GradientBoosting_train_test_k_15_29
# 30  GradientBoosting_train_test_k_15_30
# 31  GradientBoosting_train_test_k_15_31
# 32  GradientBoosting_train_test_k_15_32
# 33  GradientBoosting_train_test_k_15_33
# 34  GradientBoosting_train_test_k_15_34
# 35  GradientBoosting_train_test_k_15_35
# 36  GradientBoosting_train_test_k_15_36
# 37  GradientBoosting_train_test_k_15_37
# 38  GradientBoosting_train_test_k_15_38
# 39  GradientBoosting_train_test_k_15_39
# 40  GradientBoosting_train_test_k_15_40
# 41  GradientBoosting_train_test_k_15_41
# 42  GradientBoosting_train_test_k_15_42
# 43  GradientBoosting_train_test_k_15_43
# 44  GradientBoosting_train_test_k_15_44
# 45  GradientBoosting_train_test_k_15_45
# 46  GradientBoosting_train_test_k_15_46
# 47  GradientBoosting_train_test_k_15_47
# 48  GradientBoosting_train_test_k_15_48
# 49  GradientBoosting_train_test_k_15_49
#
#                                       Best Parameters  MSE Train  MSE Test  \
# 0   {'model__learning_rate': 0.1, 'model__max_dept...   0.311117  0.377921
# 1   {'model__learning_rate': 0.1, 'model__max_dept...   0.306062  0.366984
# 2   {'model__learning_rate': 0.1, 'model__max_dept...   0.284068  0.428183
# 3   {'model__learning_rate': 0.1, 'model__max_dept...   0.291277  0.433722
# 4   {'model__learning_rate': 0.1, 'model__max_dept...   0.306594  0.403668
# 5   {'model__learning_rate': 0.1, 'model__max_dept...   0.310814  0.395972
# 6   {'model__learning_rate': 0.1, 'model__max_dept...   0.269955  0.469309
# 7   {'model__learning_rate': 0.1, 'model__max_dept...   0.292160  0.430513
# 8   {'model__learning_rate': 0.1, 'model__max_dept...   0.301501  0.389795
# 9   {'model__learning_rate': 0.1, 'model__max_dept...   0.303869  0.415779
# 10  {'model__learning_rate': 0.1, 'model__max_dept...   0.298520  0.378574
# 11  {'model__learning_rate': 0.1, 'model__max_dept...   0.301437  0.377899
# 12  {'model__learning_rate': 0.1, 'model__max_dept...   0.323293  0.371175
# 13  {'model__learning_rate': 0.1, 'model__max_dept...   0.294990  0.415230
# 14  {'model__learning_rate': 0.1, 'model__max_dept...   0.308047  0.396014
# 15  {'model__learning_rate': 0.1, 'model__max_dept...   0.299955  0.398948
# 16  {'model__learning_rate': 0.1, 'model__max_dept...   0.305205  0.401511
# 17  {'model__learning_rate': 0.1, 'model__max_dept...   0.296761  0.398567
# 18  {'model__learning_rate': 0.1, 'model__max_dept...   0.286008  0.442052
# 19  {'model__learning_rate': 0.1, 'model__max_dept...   0.289563  0.434961
# 20  {'model__learning_rate': 0.1, 'model__max_dept...   0.300729  0.422377
# 21  {'model__learning_rate': 0.1, 'model__max_dept...   0.305298  0.387367
# 22  {'model__learning_rate': 0.1, 'model__max_dept...   0.286444  0.445384
# 23  {'model__learning_rate': 0.1, 'model__max_dept...   0.304737  0.371120
# 24  {'model__learning_rate': 0.1, 'model__max_dept...   0.297872  0.418043
# 25  {'model__learning_rate': 0.1, 'model__max_dept...   0.279651  0.453912
# 26  {'model__learning_rate': 0.1, 'model__max_dept...   0.308209  0.368577
# 27  {'model__learning_rate': 0.1, 'model__max_dept...   0.312750  0.355848
# 28  {'model__learning_rate': 0.1, 'model__max_dept...   0.280090  0.474142
# 29  {'model__learning_rate': 0.1, 'model__max_dept...   0.279454  0.493189
# 30  {'model__learning_rate': 0.1, 'model__max_dept...   0.298653  0.397148
# 31  {'model__learning_rate': 0.1, 'model__max_dept...   0.321813  0.397752
# 32  {'model__learning_rate': 0.1, 'model__max_dept...   0.298277  0.402244
# 33  {'model__learning_rate': 0.1, 'model__max_dept...   0.285902  0.432574
# 34  {'model__learning_rate': 0.1, 'model__max_dept...   0.303896  0.411485
# 35  {'model__learning_rate': 0.1, 'model__max_dept...   0.302610  0.418240
# 36  {'model__learning_rate': 0.1, 'model__max_dept...   0.283936  0.454199
# 37  {'model__learning_rate': 0.1, 'model__max_dept...   0.307005  0.401200
# 38  {'model__learning_rate': 0.1, 'model__max_dept...   0.279399  0.447057
# 39  {'model__learning_rate': 0.1, 'model__max_dept...   0.307009  0.396961
# 40  {'model__learning_rate': 0.1, 'model__max_dept...   0.289938  0.423587
# 41  {'model__learning_rate': 0.1, 'model__max_dept...   0.311971  0.364536
# 42  {'model__learning_rate': 0.1, 'model__max_dept...   0.301276  0.402613
# 43  {'model__learning_rate': 0.1, 'model__max_dept...   0.296145  0.442537
# 44  {'model__learning_rate': 0.1, 'model__max_dept...   0.299159  0.406847
# 45  {'model__learning_rate': 0.1, 'model__max_dept...   0.303736  0.376732
# 46  {'model__learning_rate': 0.1, 'model__max_dept...   0.305029  0.381319
# 47  {'model__learning_rate': 0.1, 'model__max_dept...   0.309904  0.357439
# 48  {'model__learning_rate': 0.1, 'model__max_dept...   0.307240  0.394135
# 49  {'model__learning_rate': 0.1, 'model__max_dept...   0.301591  0.406016
#
#     R2 Train   R2 Test  Best CV R2 Test  Fit Time
# 0   0.814220  0.763635         0.741929  0.371997
# 1   0.821491  0.756296         0.742771  0.327622
# 2   0.827592  0.741519         0.754140  0.318077
# 3   0.823600  0.737668         0.763727  0.316853
# 4   0.820160  0.735900         0.757692  0.343059
# 5   0.813852  0.754116         0.741709  0.320227
# 6   0.831632  0.733817         0.757759  0.273239
# 7   0.819153  0.748770         0.750147  0.321368
# 8   0.814177  0.772903         0.730891  0.328207
# 9   0.812034  0.760241         0.757855  0.338388
# 10  0.822734  0.758691         0.745863  0.310672
# 11  0.823440  0.751835         0.744640  0.317365
# 12  0.798775  0.788737         0.721262  0.325998
# 13  0.821819  0.745698         0.755012  0.318906
# 14  0.814821  0.756268         0.737865  0.331745
# 15  0.819721  0.753741         0.745145  0.300748
# 16  0.814786  0.758307         0.750614  0.314703
# 17  0.814764  0.773860         0.744028  0.333775
# 18  0.823932  0.742045         0.747405  0.346635
# 19  0.819457  0.753412         0.748557  0.281499
# 20  0.819341  0.739146         0.749242  0.422735
# 21  0.815919  0.763205         0.753912  0.351708
# 22  0.817813  0.756944         0.751292  0.372834
# 23  0.825257  0.741432         0.754538  0.493437
# 24  0.817067  0.755079         0.755959  0.341146
# 25  0.828666  0.732644         0.748588  0.345352
# 26  0.818201  0.759413         0.755921  0.317470
# 27  0.809742  0.785985         0.734470  0.343734
# 28  0.827008  0.725370         0.751329  0.331944
# 29  0.826274  0.718472         0.760963  0.341696
# 30  0.822315  0.749344         0.753551  0.389751
# 31  0.802648  0.765886         0.729664  0.309537
# 32  0.823169  0.743845         0.755413  0.354805
# 33  0.828853  0.730769         0.759615  0.348566
# 34  0.821058  0.732402         0.753855  0.334535
# 35  0.818399  0.740728         0.751046  0.364182
# 36  0.822558  0.743499         0.747340  0.293931
# 37  0.814381  0.755045         0.738459  0.333078
# 38  0.827795  0.740055         0.753837  0.344403
# 39  0.810398  0.770277         0.740475  0.228633
# 40  0.823009  0.748432         0.746834  0.349608
# 41  0.819776  0.748426         0.729928  0.291065
# 42  0.825955  0.723626         0.762517  0.372014
# 43  0.822103  0.726056         0.761741  0.348774
# 44  0.821929  0.742448         0.755994  0.461153
# 45  0.812360  0.781821         0.735800  0.335795
# 46  0.814576  0.771212         0.742442  0.447950
# 47  0.818774  0.764280         0.748827  0.361876
# 48  0.817345  0.750795         0.755340  0.332361
# 49  0.815435  0.760196         0.739967  0.337199

# %%
# Retrieve the current MLflow experiment name
mlflow_experiment_name = mlflow.get_experiment_by_name('Gradient_Boosting_Energy_train_test').name

# Construct a filename using the experiment name
filename = f"{mlflow_experiment_name}_results.csv"

# Save the DataFrame
results_df.to_csv(filename, index=False)
print(f"Results saved as {filename}")
# Out:
# Results saved as Gradient_Boosting_Energy_train_test_results.csv

# %%
# !mlflow ui
